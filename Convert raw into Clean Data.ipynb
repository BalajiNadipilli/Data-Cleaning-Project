# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\admin\Desktop\Python-Main\27th- Kaggle, Dt , time split\TASK\TASK -- convert raw data - clean data.xlsx',skiprows=2)

# %%
df
# Out:
#    Unnamed: 0           Unnamed: 1  \
# 0         NaN                  NaN
# 1         NaN                  NaN
# 2         NaN                  NaN
# 3         NaN                  NaN
# 4         NaN  THIS IS CLEAN DATA
# 5         NaN                  NaN
# 6         NaN                  NaN
#
#                                           ADDR                   DT  NAME  \
# 0  45 rd, kenith street, btm, bangalore 500038  2022-04-03 00:00:00   abc
# 1            45 rd,  street, hitech, Hd 500038  2022-04-02 00:00:00   dec
# 2                                          NaN                  NaN   NaN
# 3                                          NaN                  NaN   NaN
# 4                                          NaN                  NaN   NaN
# 5                                    House add               street  city
# 6                                        45 rd              kenith    btm
#
#       time Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# ...

# %%
df['ADDR']
# Out:
# 0    45 rd, kenith street, btm, bangalore 500038
# 1              45 rd,  street, hitech, Hd 500038
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                      House add
# 6                                          45 rd
# Name: ADDR, dtype: object

# %%
df[['HouseNO', 'Locality', 'City', 'PIN']] = df['ADDR'].str.extract(r'^(.*?),\s*(.*?),\s*(.*?)(?:,?\s*(\d{6}))?$')

'''
^: Matches the start of the string.
(.*?): Captures any characters lazily (up to the first comma ,). This corresponds to 'HouseNO'.
,\s*: Matches a comma followed by optional whitespace.
(.*?): Captures the next portion of the string (up to the next comma). This corresponds to 'Locality'.
,\s*: Matches another comma followed by optional whitespace.
(.*?): Captures the next portion (up to the end of the string or optional PIN). This corresponds to 'City'.
(?:,?\s*(\d{6}))?: Matches an optional block:
,?: Optionally matches a comma.
\s*: Matches optional whitespace.
(\d{6}): Captures exactly six digits (a PIN code). This corresponds to 'PIN'.
$: Matches the end of the string.
Result of str.extract: This method returns a DataFrame with each capture group ((...)) as a column.'''
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\admin\AppData\Local\Temp\ipykernel_7008\4121847818.py:3: SyntaxWarning: invalid escape sequence '\s'
#   '''
# ...

# %%
df
# Out:
#    Unnamed: 0           Unnamed: 1  \
# 0         NaN                  NaN
# 1         NaN                  NaN
# 2         NaN                  NaN
# 3         NaN                  NaN
# 4         NaN  THIS IS CLEAN DATA
# 5         NaN                  NaN
# 6         NaN                  NaN
#
#                                           ADDR                   DT  NAME  \
# 0  45 rd, kenith street, btm, bangalore 500038  2022-04-03 00:00:00   abc
# 1            45 rd,  street, hitech, Hd 500038  2022-04-02 00:00:00   dec
# 2                                          NaN                  NaN   NaN
# 3                                          NaN                  NaN   NaN
# 4                                          NaN                  NaN   NaN
# 5                                    House add               street  city
# 6                                        45 rd              kenith    btm
#
#       time Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# ...

# %%
df = df.iloc[:2]
df
# Out:
#    Unnamed: 0 Unnamed: 1                                         ADDR  \
# 0         NaN        NaN  45 rd, kenith street, btm, bangalore 500038
# 1         NaN        NaN            45 rd,  street, hitech, Hd 500038
#
#                     DT NAME     time Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0  2022-04-03 00:00:00  abc  8:30:21        NaN        NaN        NaN
# 1  2022-04-02 00:00:00  dec  5:30:21        NaN        NaN        NaN
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 HouseNO  \
# 0        NaN         NaN         NaN         NaN         NaN   45 rd
# 1        NaN         NaN         NaN         NaN         NaN   45 rd
#
#         Locality            City     PIN
# 0  kenith street  btm, bangalore  500038
# 1         street      hitech, Hd  500038

# %%
df = df.dropna(axis=1)
df
# Out:
#                                           ADDR                   DT NAME  \
# 0  45 rd, kenith street, btm, bangalore 500038  2022-04-03 00:00:00  abc
# 1            45 rd,  street, hitech, Hd 500038  2022-04-02 00:00:00  dec
#
#       time HouseNO       Locality            City     PIN
# 0  8:30:21   45 rd  kenith street  btm, bangalore  500038
# 1  5:30:21   45 rd         street      hitech, Hd  500038

# %%
df = df.drop('ADDR',axis=1)
df
# Out:
#                     DT NAME     time HouseNO       Locality            City  \
# 0  2022-04-03 00:00:00  abc  8:30:21   45 rd  kenith street  btm, bangalore
# 1  2022-04-02 00:00:00  dec  5:30:21   45 rd         street      hitech, Hd
#
#       PIN
# 0  500038
# 1  500038

# %%
df['DT']
# Out:
# 0    2022-04-03 00:00:00
# 1    2022-04-02 00:00:00
# Name: DT, dtype: object

# %%
df['Date'] = pd.to_datetime(df['DT']).dt.date 
#Converts the column DT (which likely contains strings or timestamps) into pandas datetime objects.
df
# Out:
#                     DT NAME     time HouseNO       Locality            City  \
# 0  2022-04-03 00:00:00  abc  8:30:21   45 rd  kenith street  btm, bangalore
# 1  2022-04-02 00:00:00  dec  5:30:21   45 rd         street      hitech, Hd
#
#       PIN        Date
# 0  500038  2022-04-03
# 1  500038  2022-04-02

# %%
df = df.drop('DT',axis=1)
df
# Out:
#   NAME     time HouseNO       Locality            City     PIN        Date
# 0  abc  8:30:21   45 rd  kenith street  btm, bangalore  500038  2022-04-03
# 1  dec  5:30:21   45 rd         street      hitech, Hd  500038  2022-04-02

# %%
df['Year'] = pd.to_datetime(df['Date']).dt.year
df['Month'] = pd.to_datetime(df['Date']).dt.month
df['Day'] = pd.to_datetime(df['Date']).dt.day

df
# Out:
#   NAME     time HouseNO       Locality            City     PIN        Date  \
# 0  abc  8:30:21   45 rd  kenith street  btm, bangalore  500038  2022-04-03
# 1  dec  5:30:21   45 rd         street      hitech, Hd  500038  2022-04-02
#
#    Year  Month  Day
# 0  2022      4    3
# 1  2022      4    2

# %%
df[['Hour', 'Minute', 'Second']] = df['time'].str.split(':', expand=True)
df
# Out:
#   NAME     time HouseNO       Locality            City     PIN        Date  \
# 0  abc  8:30:21   45 rd  kenith street  btm, bangalore  500038  2022-04-03
# 1  dec  5:30:21   45 rd         street      hitech, Hd  500038  2022-04-02
#
#    Year  Month  Day Hour Minute Second
# 0  2022      4    3    8     30     21
# 1  2022      4    2    5     30     21

# %%
df = df.drop(['Date','time'], axis=1)
df
# Out:
#   NAME HouseNO       Locality            City     PIN  Year  Month  Day Hour  \
# 0  abc   45 rd  kenith street  btm, bangalore  500038  2022      4    3    8
# 1  dec   45 rd         street      hitech, Hd  500038  2022      4    2    5
#
#   Minute Second
# 0     30     21
# 1     30     21
